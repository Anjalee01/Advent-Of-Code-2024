# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjalee01/Advent-Of-Code-2024/blob/main/Day12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def flood_fill(grid, x, y, visited, plant_type):
    """Performs flood-fill to find a region and calculates its area and perimeter."""
    rows, cols = len(grid), len(grid[0])
    stack = [(x, y)]
    area = 0
    perimeter = 0
    visited.add((x, y))

    # Directions for movement: up, down, left, right
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    while stack:
        cx, cy = stack.pop()
        area += 1

        for dx, dy in directions:
            nx, ny = cx + dx, cy + dy
            if 0 <= nx < rows and 0 <= ny < cols:
                if grid[nx][ny] == plant_type:
                    if (nx, ny) not in visited:
                        visited.add((nx, ny))
                        stack.append((nx, ny))
                else:
                    # Edge of the region
                    perimeter += 1
            else:
                # Edge of the grid
                perimeter += 1

    return area, perimeter


def calculate_fencing_cost(grid):
    """Calculates the total fencing cost for the garden."""
    rows, cols = len(grid), len(grid[0])
    visited = set()
    total_cost = 0

    for x in range(rows):
        for y in range(cols):
            if (x, y) not in visited:
                # Start a new region for a specific plant type
                plant_type = grid[x][y]
                area, perimeter = flood_fill(grid, x, y, visited, plant_type)
                cost = area * perimeter
                total_cost += cost
                print(f"Region {plant_type}: Area={area}, Perimeter={perimeter}, Cost={cost}")

    return total_cost


def read_map(file_path):
    """Reads the garden map from a file."""
    with open(file_path, 'r') as file:
        return [line.strip() for line in file.readlines()]


def main():
    # Read the garden map from the input file
    file_path = "input.txt"
    garden_map = read_map(file_path)

    # Calculate the total fencing cost
    total_cost = calculate_fencing_cost(garden_map)

    # Output the result
    print("Total fencing cost:", total_cost)


if __name__ == "__main__":
    main()
# Out:
# Region O: Area=10, Perimeter=22, Cost=220
# Region K: Area=122, Perimeter=74, Cost=9028
# Region T: Area=96, Perimeter=78, Cost=7488
# Region C: Area=5, Perimeter=12, Cost=60
# Region Y: Area=88, Perimeter=64, Cost=5632
# Region G: Area=212, Perimeter=198, Cost=41976
# Region M: Area=16, Perimeter=28, Cost=448
# Region F: Area=1, Perimeter=4, Cost=4
# Region P: Area=136, Perimeter=100, Cost=13600
# Region D: Area=1, Perimeter=4, Cost=4
# Region S: Area=150, Perimeter=74, Cost=11100
# Region Y: Area=86, Perimeter=54, Cost=4644
# Region T: Area=22, Perimeter=32, Cost=704
# Region Z: Area=55, Perimeter=48, Cost=2640
# Region C: Area=29, Perimeter=30, Cost=870
# Region P: Area=146, Perimeter=82, Cost=11972
# Region Z: Area=1, Perimeter=4, Cost=4
# Region R: Area=7, Perimeter=14, Cost=98
# Region Q: Area=57, Perimeter=50, Cost=2850
# Region J: Area=30, Perimeter=34, Cost=1020
# Region L: Area=145, Perimeter=102, Cost=14790
# Region I: Area=362, Perimeter=196, Cost=70952
# Region V: Area=3, Perimeter=8, Cost=24
# Region J: Area=27, Perimeter=34, Cost=918
# Region Z: Area=1, Perimeter=4, Cost=4
# Region B: Area=64, Perimeter=54, Cost=3456
# Region G: Area=85, Perimeter=56, Cost=4760
# Region A: Area=1, Perimeter=4, Cost=4
# Region O: Area=1, Perimeter=4, Cost=4
# Region Y: Area=4, Perimeter=8, Cost=32
# Region H: Area=1, Perimeter=4, Cost=4
# Region T: Area=1, Perimeter=4, Cost=4
# Region R: Area=3, Perimeter=8, Cost=24
# Region X: Area=1, Perimeter=4, Cost=4
# Region H: Area=241, Perimeter=124, Cost=29884
# Region A: Area=1, Perimeter=4, Cost=4
# Region X: Area=1, Perimeter=4, Cost=4
# Region R: Area=6, Perimeter=12, Cost=72
# Region A: Area=56, Perimeter=48, Cost=2688
# Region V: Area=11, Perimeter=16, Cost=176
# Region N: Area=58, Perimeter=74, Cost=4292
# Region C: Area=18, Perimeter=26, Cost=468
# Region E: Area=1, Perimeter=4, Cost=4
# Region S: Area=2, Perimeter=6, Cost=12
# Region O: Area=10, Perimeter=18, Cost=180
# Region D: Area=8, Perimeter=16, Cost=128
# Region I: Area=2, Perimeter=6, Cost=12
# Region J: Area=35, Perimeter=32, Cost=1120
# Region I: Area=1, Perimeter=4, Cost=4
# Region C: Area=75, Perimeter=52, Cost=3900
# Region S: Area=1, Perimeter=4, Cost=4
# Region M: Area=50, Perimeter=42, Cost=2100
# Region T: Area=1, Perimeter=4, Cost=4
# Region R: Area=3, Perimeter=8, Cost=24
# Region L: Area=1, Perimeter=4, Cost=4
# Region K: Area=36, Perimeter=52, Cost=1872
# Region D: Area=38, Perimeter=32, Cost=1216
# Region W: Area=1, Perimeter=4, Cost=4
# Region R: Area=1, Perimeter=4, Cost=4
# Region J: Area=49, Perimeter=40, Cost=1960
# Region L: Area=3, Perimeter=8, Cost=24
# Region S: Area=1, Perimeter=4, Cost=4
# Region Q: Area=1, Perimeter=4, Cost=4
# Region A: Area=106, Perimeter=58, Cost=6148
# Region V: Area=40, Perimeter=38, Cost=1520
# Region H: Area=1, Perimeter=4, Cost=4
# Region O: Area=1, Perimeter=4, Cost=4
# Region I: Area=5, Perimeter=10, Cost=50
# Region Y: Area=1, Perimeter=4, Cost=4
# Region T: Area=1, Perimeter=4, Cost=4
# Region R: Area=1, Perimeter=4, Cost=4
# Region G: Area=1, Perimeter=4, Cost=4
# Region H: Area=70, Perimeter=64, Cost=4480
# Region F: Area=190, Perimeter=176, Cost=33440
# Region D: Area=90, Perimeter=70, Cost=6300
# Region I: Area=80, Perimeter=82, Cost=6560
# Region W: Area=31, Perimeter=38, Cost=1178
# Region V: Area=66, Perimeter=50, Cost=3300
# Region F: Area=1, Perimeter=4, Cost=4
# Region M: Area=1, Perimeter=4, Cost=4
# Region Q: Area=53, Perimeter=62, Cost=3286
# Region L: Area=1, Perimeter=4, Cost=4
# Region E: Area=1, Perimeter=4, Cost=4
# Region I: Area=2, Perimeter=6, Cost=12
# Region G: Area=14, Perimeter=20, Cost=280
# Region L: Area=2, Perimeter=6, Cost=12
# Region P: Area=240, Perimeter=96, Cost=23040
# Region L: Area=2, Perimeter=6, Cost=12
# Region S: Area=1, Perimeter=4, Cost=4
# Region N: Area=1, Perimeter=4, Cost=4
# Region L: Area=24, Perimeter=32, Cost=768
# Region K: Area=2, Perimeter=6, Cost=12
# Region Y: Area=1, Perimeter=4, Cost=4
# Region C: Area=1, Perimeter=4, Cost=4
# Region C: Area=25, Perimeter=32, Cost=800
# Region O: Area=24, Perimeter=28, Cost=672
# Region X: Area=1, Perimeter=4, Cost=4
# Region F: Area=15, Perimeter=22, Cost=330
# Region A: Area=1, Perimeter=4, Cost=4
# Region X: Area=31, Perimeter=32, Cost=992
# Region V: Area=156, Perimeter=130, Cost=20280
# Region U: Area=13, Perimeter=22, Cost=286
# Region C: Area=2, Perimeter=6, Cost=12
# Region L: Area=3, Perimeter=8, Cost=24
# Region D: Area=56, Perimeter=54, Cost=3024
# Region R: Area=1, Perimeter=4, Cost=4
# Region N: Area=1, Perimeter=4, Cost=4
# Region D: Area=1, Perimeter=4, Cost=4
# Region W: Area=24, Perimeter=40, Cost=960
# Region P: Area=71, Perimeter=66, Cost=4686
# Region W: Area=1, Perimeter=4, Cost=4
# Region P: Area=4, Perimeter=10, Cost=40
# Region M: Area=82, Perimeter=74, Cost=6068
# Region X: Area=26, Perimeter=26, Cost=676
# Region G: Area=2, Perimeter=6, Cost=12
# Region U: Area=10, Perimeter=16, Cost=160
# Region F: Area=120, Perimeter=82, Cost=9840
# Region Z: Area=18, Perimeter=24, Cost=432
# Region T: Area=42, Perimeter=42, Cost=1764
# Region V: Area=8, Perimeter=14, Cost=112
# Region W: Area=35, Perimeter=50, Cost=1750
# Region R: Area=1, Perimeter=4, Cost=4
# Region O: Area=1, Perimeter=4, Cost=4
# Region R: Area=138, Perimeter=86, Cost=11868
# Region Y: Area=1, Perimeter=4, Cost=4
# Region M: Area=7, Perimeter=14, Cost=98
# Region Y: Area=63, Perimeter=44, Cost=2772
# Region P: Area=10, Perimeter=18, Cost=180
# Region O: Area=1, Perimeter=4, Cost=4
# Region N: Area=5, Perimeter=10, Cost=50
# Region I: Area=2, Perimeter=6, Cost=12
# Region X: Area=1, Perimeter=4, Cost=4
# Region U: Area=31, Perimeter=32, Cost=992
# Region J: Area=9, Perimeter=14, Cost=126
# Region A: Area=1, Perimeter=4, Cost=4
# Region E: Area=1, Perimeter=4, Cost=4
# Region A: Area=91, Perimeter=82, Cost=7462
# Region K: Area=2, Perimeter=6, Cost=12
# Region J: Area=1, Perimeter=4, Cost=4
# Region X: Area=1, Perimeter=4, Cost=4
# Region K: Area=88, Perimeter=54, Cost=4752
# Region S: Area=126, Perimeter=76, Cost=9576
# Region Z: Area=2, Perimeter=6, Cost=12
# Region G: Area=77, Perimeter=58, Cost=4466
# Region W: Area=1, Perimeter=4, Cost=4
# Region L: Area=3, Perimeter=8, Cost=24
# Region K: Area=1, Perimeter=4, Cost=4
# Region X: Area=17, Perimeter=28, Cost=476
# Region V: Area=21, Perimeter=24, Cost=504
# Region J: Area=9, Perimeter=16, Cost=144
# Region Q: Area=2, Perimeter=6, Cost=12
# Region L: Area=20, Perimeter=28, Cost=560
# Region V: Area=1, Perimeter=4, Cost=4
# Region U: Area=22, Perimeter=30, Cost=660
# Region C: Area=53, Perimeter=66, Cost=3498
# Region D: Area=84, Perimeter=74, Cost=6216
# Region Z: Area=39, Perimeter=44, Cost=1716
# Region J: Area=1, Perimeter=4, Cost=4
# Region U: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region M: Area=5, Perimeter=12, Cost=60
# Region V: Area=144, Perimeter=130, Cost=18720
# Region Q: Area=124, Perimeter=84, Cost=10416
# Region D: Area=1, Perimeter=4, Cost=4
# Region G: Area=46, Perimeter=50, Cost=2300
# Region G: Area=78, Perimeter=54, Cost=4212
# Region C: Area=1, Perimeter=4, Cost=4
# Region A: Area=103, Perimeter=70, Cost=7210
# Region S: Area=1, Perimeter=4, Cost=4
# Region W: Area=7, Perimeter=14, Cost=98
# Region O: Area=60, Perimeter=56, Cost=3360
# Region D: Area=3, Perimeter=8, Cost=24
# Region L: Area=107, Perimeter=88, Cost=9416
# Region N: Area=8, Perimeter=14, Cost=112
# Region O: Area=1, Perimeter=4, Cost=4
# Region E: Area=1, Perimeter=4, Cost=4
# Region J: Area=50, Perimeter=48, Cost=2400
# Region Q: Area=1, Perimeter=4, Cost=4
# Region G: Area=1, Perimeter=4, Cost=4
# Region U: Area=1, Perimeter=4, Cost=4
# Region M: Area=81, Perimeter=50, Cost=4050
# Region I: Area=57, Perimeter=54, Cost=3078
# Region Q: Area=5, Perimeter=12, Cost=60
# Region D: Area=1, Perimeter=4, Cost=4
# Region K: Area=32, Perimeter=38, Cost=1216
# Region B: Area=20, Perimeter=36, Cost=720
# Region M: Area=2, Perimeter=6, Cost=12
# Region R: Area=2, Perimeter=6, Cost=12
# Region E: Area=1, Perimeter=4, Cost=4
# Region B: Area=1, Perimeter=4, Cost=4
# Region Y: Area=29, Perimeter=36, Cost=1044
# Region J: Area=100, Perimeter=60, Cost=6000
# Region T: Area=1, Perimeter=4, Cost=4
# Region Q: Area=2, Perimeter=6, Cost=12
# Region X: Area=2, Perimeter=6, Cost=12
# Region U: Area=27, Perimeter=34, Cost=918
# Region C: Area=12, Perimeter=20, Cost=240
# Region S: Area=1, Perimeter=4, Cost=4
# Region I: Area=131, Perimeter=74, Cost=9694
# Region R: Area=1, Perimeter=4, Cost=4
# Region A: Area=1, Perimeter=4, Cost=4
# Region W: Area=38, Perimeter=62, Cost=2356
# Region W: Area=55, Perimeter=70, Cost=3850
# Region B: Area=2, Perimeter=6, Cost=12
# Region S: Area=25, Perimeter=30, Cost=750
# Region S: Area=5, Perimeter=12, Cost=60
# Region F: Area=121, Perimeter=58, Cost=7018
# Region W: Area=3, Perimeter=8, Cost=24
# Region K: Area=54, Perimeter=40, Cost=2160
# Region N: Area=4, Perimeter=10, Cost=40
# Region K: Area=2, Perimeter=6, Cost=12
# Region W: Area=1, Perimeter=4, Cost=4
# Region C: Area=77, Perimeter=76, Cost=5852
# Region F: Area=86, Perimeter=72, Cost=6192
# Region P: Area=1, Perimeter=4, Cost=4
# Region I: Area=108, Perimeter=118, Cost=12744
# Region S: Area=84, Perimeter=66, Cost=5544
# Region A: Area=5, Perimeter=10, Cost=50
# Region S: Area=1, Perimeter=4, Cost=4
# Region O: Area=80, Perimeter=66, Cost=5280
# Region M: Area=1, Perimeter=4, Cost=4
# Region W: Area=1, Perimeter=4, Cost=4
# Region K: Area=105, Perimeter=68, Cost=7140
# Region X: Area=184, Perimeter=142, Cost=26128
# Region Q: Area=62, Perimeter=66, Cost=4092
# Region A: Area=143, Perimeter=84, Cost=12012
# Region R: Area=1, Perimeter=4, Cost=4
# Region L: Area=1, Perimeter=4, Cost=4
# Region X: Area=24, Perimeter=30, Cost=720
# Region R: Area=24, Perimeter=34, Cost=816
# Region X: Area=1, Perimeter=4, Cost=4
# Region H: Area=2, Perimeter=6, Cost=12
# Region A: Area=1, Perimeter=4, Cost=4
# Region R: Area=43, Perimeter=40, Cost=1720
# Region D: Area=77, Perimeter=58, Cost=4466
# Region J: Area=1, Perimeter=4, Cost=4
# Region D: Area=6, Perimeter=14, Cost=84
# Region O: Area=237, Perimeter=182, Cost=43134
# Region W: Area=2, Perimeter=6, Cost=12
# Region Q: Area=61, Perimeter=50, Cost=3050
# Region T: Area=2, Perimeter=6, Cost=12
# Region S: Area=1, Perimeter=4, Cost=4
# Region J: Area=1, Perimeter=4, Cost=4
# Region G: Area=1, Perimeter=4, Cost=4
# Region X: Area=70, Perimeter=56, Cost=3920
# Region Y: Area=2, Perimeter=6, Cost=12
# Region P: Area=1, Perimeter=4, Cost=4
# Region W: Area=105, Perimeter=64, Cost=6720
# Region T: Area=13, Perimeter=24, Cost=312
# Region G: Area=27, Perimeter=38, Cost=1026
# Region N: Area=1, Perimeter=4, Cost=4
# Region D: Area=9, Perimeter=16, Cost=144
# Region V: Area=1, Perimeter=4, Cost=4
# Region N: Area=1, Perimeter=4, Cost=4
# Region L: Area=1, Perimeter=4, Cost=4
# Region M: Area=100, Perimeter=72, Cost=7200
# Region G: Area=101, Perimeter=68, Cost=6868
# Region C: Area=6, Perimeter=14, Cost=84
# Region J: Area=182, Perimeter=164, Cost=29848
# Region Z: Area=1, Perimeter=4, Cost=4
# Region E: Area=1, Perimeter=4, Cost=4
# Region F: Area=1, Perimeter=4, Cost=4
# Region D: Area=27, Perimeter=34, Cost=918
# Region W: Area=31, Perimeter=28, Cost=868
# Region G: Area=1, Perimeter=4, Cost=4
# Region P: Area=152, Perimeter=86, Cost=13072
# Region B: Area=16, Perimeter=24, Cost=384
# Region I: Area=1, Perimeter=4, Cost=4
# Region R: Area=3, Perimeter=8, Cost=24
# Region Y: Area=2, Perimeter=6, Cost=12
# Region I: Area=2, Perimeter=6, Cost=12
# Region P: Area=1, Perimeter=4, Cost=4
# Region X: Area=1, Perimeter=4, Cost=4
# Region Z: Area=45, Perimeter=44, Cost=1980
# Region Q: Area=1, Perimeter=4, Cost=4
# Region M: Area=11, Perimeter=16, Cost=176
# Region A: Area=1, Perimeter=4, Cost=4
# Region T: Area=5, Perimeter=12, Cost=60
# Region U: Area=1, Perimeter=4, Cost=4
# Region I: Area=1, Perimeter=4, Cost=4
# Region D: Area=63, Perimeter=56, Cost=3528
# Region N: Area=2, Perimeter=6, Cost=12
# Region C: Area=3, Perimeter=8, Cost=24
# Region K: Area=58, Perimeter=46, Cost=2668
# Region V: Area=1, Perimeter=4, Cost=4
# Region L: Area=1, Perimeter=4, Cost=4
# Region N: Area=5, Perimeter=10, Cost=50
# Region V: Area=1, Perimeter=4, Cost=4
# Region O: Area=9, Perimeter=16, Cost=144
# Region X: Area=3, Perimeter=8, Cost=24
# Region S: Area=1, Perimeter=4, Cost=4
# Region Z: Area=130, Perimeter=64, Cost=8320
# Region K: Area=24, Perimeter=28, Cost=672
# Region Z: Area=1, Perimeter=4, Cost=4
# Region R: Area=46, Perimeter=52, Cost=2392
# Region D: Area=1, Perimeter=4, Cost=4
# Region N: Area=32, Perimeter=34, Cost=1088
# Region X: Area=2, Perimeter=6, Cost=12
# Region I: Area=113, Perimeter=76, Cost=8588
# Region X: Area=1, Perimeter=4, Cost=4
# Region Y: Area=1, Perimeter=4, Cost=4
# Region E: Area=3, Perimeter=8, Cost=24
# Region A: Area=1, Perimeter=4, Cost=4
# Region Y: Area=76, Perimeter=60, Cost=4560
# Region X: Area=2, Perimeter=6, Cost=12
# Region X: Area=2, Perimeter=6, Cost=12
# Region C: Area=1, Perimeter=4, Cost=4
# Region E: Area=5, Perimeter=10, Cost=50
# Region I: Area=1, Perimeter=4, Cost=4
# Region W: Area=1, Perimeter=4, Cost=4
# Region D: Area=2, Perimeter=6, Cost=12
# Region J: Area=19, Perimeter=20, Cost=380
# Region X: Area=84, Perimeter=66, Cost=5544
# Region X: Area=4, Perimeter=10, Cost=40
# Region M: Area=106, Perimeter=86, Cost=9116
# Region X: Area=16, Perimeter=22, Cost=352
# Region G: Area=2, Perimeter=6, Cost=12
# Region A: Area=1, Perimeter=4, Cost=4
# Region C: Area=1, Perimeter=4, Cost=4
# Region A: Area=1, Perimeter=4, Cost=4
# Region Y: Area=53, Perimeter=60, Cost=3180
# Region E: Area=98, Perimeter=42, Cost=4116
# Region C: Area=1, Perimeter=4, Cost=4
# Region O: Area=40, Perimeter=26, Cost=1040
# Region K: Area=1, Perimeter=4, Cost=4
# Region Q: Area=142, Perimeter=90, Cost=12780
# Region Y: Area=7, Perimeter=12, Cost=84
# Region N: Area=2, Perimeter=6, Cost=12
# Region N: Area=2, Perimeter=6, Cost=12
# Region B: Area=41, Perimeter=46, Cost=1886
# Region E: Area=2, Perimeter=6, Cost=12
# Region S: Area=49, Perimeter=42, Cost=2058
# Region W: Area=23, Perimeter=28, Cost=644
# Region X: Area=115, Perimeter=92, Cost=10580
# Region V: Area=1, Perimeter=4, Cost=4
# Region E: Area=73, Perimeter=68, Cost=4964
# Region P: Area=2, Perimeter=6, Cost=12
# Region Q: Area=2, Perimeter=6, Cost=12
# Region L: Area=1, Perimeter=4, Cost=4
# Region P: Area=20, Perimeter=20, Cost=400
# Region N: Area=2, Perimeter=6, Cost=12
# Region P: Area=86, Perimeter=58, Cost=4988
# Region H: Area=2, Perimeter=6, Cost=12
# Region G: Area=7, Perimeter=16, Cost=112
# Region A: Area=82, Perimeter=66, Cost=5412
# Region N: Area=184, Perimeter=108, Cost=19872
# Region B: Area=146, Perimeter=98, Cost=14308
# Region V: Area=1, Perimeter=4, Cost=4
# Region T: Area=1, Perimeter=4, Cost=4
# Region H: Area=24, Perimeter=32, Cost=768
# Region W: Area=1, Perimeter=4, Cost=4
# Region D: Area=23, Perimeter=34, Cost=782
# Region N: Area=2, Perimeter=6, Cost=12
# Region U: Area=1, Perimeter=4, Cost=4
# Region E: Area=3, Perimeter=8, Cost=24
# Region L: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region N: Area=12, Perimeter=22, Cost=264
# Region E: Area=67, Perimeter=46, Cost=3082
# Region H: Area=1, Perimeter=4, Cost=4
# Region Z: Area=67, Perimeter=58, Cost=3886
# Region D: Area=1, Perimeter=4, Cost=4
# Region A: Area=19, Perimeter=32, Cost=608
# Region Q: Area=1, Perimeter=4, Cost=4
# Region J: Area=1, Perimeter=4, Cost=4
# Region M: Area=127, Perimeter=84, Cost=10668
# Region Z: Area=1, Perimeter=4, Cost=4
# Region W: Area=1, Perimeter=4, Cost=4
# Region E: Area=102, Perimeter=96, Cost=9792
# Region Z: Area=21, Perimeter=24, Cost=504
# Region F: Area=3, Perimeter=8, Cost=24
# Region R: Area=2, Perimeter=6, Cost=12
# Region I: Area=2, Perimeter=6, Cost=12
# Region H: Area=8, Perimeter=14, Cost=112
# Region K: Area=1, Perimeter=4, Cost=4
# Region N: Area=3, Perimeter=8, Cost=24
# Region G: Area=62, Perimeter=46, Cost=2852
# Region E: Area=1, Perimeter=4, Cost=4
# Region H: Area=156, Perimeter=62, Cost=9672
# Region Q: Area=1, Perimeter=4, Cost=4
# Region O: Area=41, Perimeter=52, Cost=2132
# Region A: Area=70, Perimeter=50, Cost=3500
# Region S: Area=2, Perimeter=6, Cost=12
# Region I: Area=204, Perimeter=86, Cost=17544
# Region L: Area=1, Perimeter=4, Cost=4
# Region R: Area=1, Perimeter=4, Cost=4
# Region S: Area=119, Perimeter=80, Cost=9520
# Region G: Area=6, Perimeter=10, Cost=60
# Region B: Area=15, Perimeter=22, Cost=330
# Region S: Area=2, Perimeter=6, Cost=12
# Region R: Area=6, Perimeter=12, Cost=72
# Region H: Area=4, Perimeter=8, Cost=32
# Region S: Area=98, Perimeter=74, Cost=7252
# Region Y: Area=75, Perimeter=68, Cost=5100
# Region Z: Area=75, Perimeter=56, Cost=4200
# Region B: Area=2, Perimeter=6, Cost=12
# Region X: Area=1, Perimeter=4, Cost=4
# Region F: Area=3, Perimeter=8, Cost=24
# Region D: Area=41, Perimeter=40, Cost=1640
# Region X: Area=13, Perimeter=18, Cost=234
# Region L: Area=62, Perimeter=46, Cost=2852
# Region N: Area=4, Perimeter=8, Cost=32
# Region G: Area=15, Perimeter=20, Cost=300
# Region V: Area=111, Perimeter=126, Cost=13986
# Region M: Area=1, Perimeter=4, Cost=4
# Region Y: Area=7, Perimeter=14, Cost=98
# Region K: Area=67, Perimeter=38, Cost=2546
# Region H: Area=1, Perimeter=4, Cost=4
# Region Y: Area=2, Perimeter=6, Cost=12
# Region B: Area=16, Perimeter=16, Cost=256
# Region U: Area=1, Perimeter=4, Cost=4
# Region S: Area=22, Perimeter=28, Cost=616
# Region J: Area=148, Perimeter=94, Cost=13912
# Region M: Area=49, Perimeter=44, Cost=2156
# Region R: Area=5, Perimeter=12, Cost=60
# Region E: Area=2, Perimeter=6, Cost=12
# Region H: Area=62, Perimeter=62, Cost=3844
# Region L: Area=29, Perimeter=34, Cost=986
# Region Z: Area=18, Perimeter=24, Cost=432
# Region V: Area=59, Perimeter=62, Cost=3658
# Region G: Area=84, Perimeter=56, Cost=4704
# Region T: Area=2, Perimeter=6, Cost=12
# Region V: Area=7, Perimeter=12, Cost=84
# Region I: Area=1, Perimeter=4, Cost=4
# Region C: Area=76, Perimeter=78, Cost=5928
# Region O: Area=94, Perimeter=92, Cost=8648
# Region I: Area=101, Perimeter=76, Cost=7676
# Region U: Area=12, Perimeter=22, Cost=264
# Region D: Area=1, Perimeter=4, Cost=4
# Region C: Area=5, Perimeter=10, Cost=50
# Region O: Area=3, Perimeter=8, Cost=24
# Region R: Area=131, Perimeter=82, Cost=10742
# Region N: Area=1, Perimeter=4, Cost=4
# Region V: Area=1, Perimeter=4, Cost=4
# Region J: Area=106, Perimeter=72, Cost=7632
# Region N: Area=30, Perimeter=32, Cost=960
# Region W: Area=84, Perimeter=66, Cost=5544
# Region N: Area=1, Perimeter=4, Cost=4
# Region A: Area=4, Perimeter=10, Cost=40
# Region S: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region C: Area=1, Perimeter=4, Cost=4
# Region B: Area=1, Perimeter=4, Cost=4
# Region S: Area=107, Perimeter=76, Cost=8132
# Region J: Area=9, Perimeter=16, Cost=144
# Region Z: Area=65, Perimeter=60, Cost=3900
# Region L: Area=5, Perimeter=12, Cost=60
# Region Q: Area=41, Perimeter=38, Cost=1558
# Region P: Area=283, Perimeter=194, Cost=54902
# Region Z: Area=13, Perimeter=20, Cost=260
# Region L: Area=94, Perimeter=68, Cost=6392
# Region E: Area=1, Perimeter=4, Cost=4
# Region H: Area=38, Perimeter=42, Cost=1596
# Region M: Area=2, Perimeter=6, Cost=12
# Region Y: Area=112, Perimeter=74, Cost=8288
# Region B: Area=32, Perimeter=34, Cost=1088
# Region F: Area=1, Perimeter=4, Cost=4
# Region O: Area=54, Perimeter=40, Cost=2160
# Region T: Area=1, Perimeter=4, Cost=4
# Region X: Area=1, Perimeter=4, Cost=4
# Region Z: Area=73, Perimeter=76, Cost=5548
# Region I: Area=1, Perimeter=4, Cost=4
# Region G: Area=1, Perimeter=4, Cost=4
# Region B: Area=3, Perimeter=8, Cost=24
# Region M: Area=10, Perimeter=14, Cost=140
# Region P: Area=129, Perimeter=74, Cost=9546
# Region Y: Area=1, Perimeter=4, Cost=4
# Region N: Area=1, Perimeter=4, Cost=4
# Region Z: Area=94, Perimeter=82, Cost=7708
# Region C: Area=1, Perimeter=4, Cost=4
# Region I: Area=1, Perimeter=4, Cost=4
# Region P: Area=1, Perimeter=4, Cost=4
# Region Z: Area=1, Perimeter=4, Cost=4
# Region B: Area=100, Perimeter=64, Cost=6400
# Region L: Area=29, Perimeter=24, Cost=696
# Region N: Area=1, Perimeter=4, Cost=4
# Region Q: Area=10, Perimeter=18, Cost=180
# Region R: Area=4, Perimeter=10, Cost=40
# Region L: Area=43, Perimeter=58, Cost=2494
# Region Z: Area=20, Perimeter=22, Cost=440
# Region G: Area=1, Perimeter=4, Cost=4
# Region G: Area=2, Perimeter=6, Cost=12
# Region W: Area=1, Perimeter=4, Cost=4
# Region K: Area=4, Perimeter=10, Cost=40
# Region P: Area=1, Perimeter=4, Cost=4
# Region F: Area=107, Perimeter=90, Cost=9630
# Region M: Area=150, Perimeter=94, Cost=14100
# Region E: Area=143, Perimeter=90, Cost=12870
# Region Q: Area=10, Perimeter=18, Cost=180
# Region K: Area=96, Perimeter=64, Cost=6144
# Region R: Area=1, Perimeter=4, Cost=4
# Region D: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region G: Area=54, Perimeter=46, Cost=2484
# Region B: Area=143, Perimeter=94, Cost=13442
# Region U: Area=97, Perimeter=56, Cost=5432
# Region U: Area=3, Perimeter=8, Cost=24
# Region I: Area=22, Perimeter=30, Cost=660
# Region O: Area=107, Perimeter=90, Cost=9630
# Region K: Area=1, Perimeter=4, Cost=4
# Region O: Area=2, Perimeter=6, Cost=12
# Region Z: Area=1, Perimeter=4, Cost=4
# Region V: Area=1, Perimeter=4, Cost=4
# Region P: Area=1, Perimeter=4, Cost=4
# Region H: Area=21, Perimeter=28, Cost=588
# Region L: Area=1, Perimeter=4, Cost=4
# Region O: Area=2, Perimeter=6, Cost=12
# Region S: Area=1, Perimeter=4, Cost=4
# Region F: Area=3, Perimeter=8, Cost=24
# Region Q: Area=148, Perimeter=54, Cost=7992
# Region X: Area=25, Perimeter=22, Cost=550
# Region M: Area=105, Perimeter=68, Cost=7140
# Region D: Area=124, Perimeter=86, Cost=10664
# Region X: Area=96, Perimeter=66, Cost=6336
# Region U: Area=48, Perimeter=50, Cost=2400
# Region Q: Area=95, Perimeter=64, Cost=6080
# Region S: Area=49, Perimeter=50, Cost=2450
# Region E: Area=16, Perimeter=22, Cost=352
# Region Y: Area=47, Perimeter=38, Cost=1786
# Region X: Area=6, Perimeter=14, Cost=84
# Region R: Area=1, Perimeter=4, Cost=4
# Region V: Area=1, Perimeter=4, Cost=4
# Region Q: Area=2, Perimeter=6, Cost=12
# Region J: Area=1, Perimeter=4, Cost=4
# Region Z: Area=90, Perimeter=112, Cost=10080
# Region W: Area=256, Perimeter=158, Cost=40448
# Region E: Area=77, Perimeter=60, Cost=4620
# Region H: Area=2, Perimeter=6, Cost=12
# Region U: Area=91, Perimeter=80, Cost=7280
# Region F: Area=23, Perimeter=28, Cost=644
# Region O: Area=7, Perimeter=12, Cost=84
# Region J: Area=1, Perimeter=4, Cost=4
# Region R: Area=293, Perimeter=204, Cost=59772
# Region J: Area=2, Perimeter=6, Cost=12
# Region Y: Area=1, Perimeter=4, Cost=4
# Region C: Area=51, Perimeter=56, Cost=2856
# Region G: Area=1, Perimeter=4, Cost=4
# Region B: Area=33, Perimeter=40, Cost=1320
# Region O: Area=2, Perimeter=6, Cost=12
# Region D: Area=42, Perimeter=40, Cost=1680
# Region O: Area=14, Perimeter=22, Cost=308
# Region X: Area=1, Perimeter=4, Cost=4
# Region R: Area=3, Perimeter=8, Cost=24
# Region I: Area=1, Perimeter=4, Cost=4
# Region M: Area=5, Perimeter=12, Cost=60
# Region S: Area=2, Perimeter=6, Cost=12
# Region F: Area=91, Perimeter=56, Cost=5096
# Region D: Area=1, Perimeter=4, Cost=4
# Region S: Area=139, Perimeter=80, Cost=11120
# Region G: Area=109, Perimeter=74, Cost=8066
# Region R: Area=40, Perimeter=36, Cost=1440
# Region H: Area=1, Perimeter=4, Cost=4
# Region T: Area=159, Perimeter=98, Cost=15582
# Region H: Area=2, Perimeter=6, Cost=12
# Region F: Area=2, Perimeter=6, Cost=12
# Region B: Area=1, Perimeter=4, Cost=4
# Region Q: Area=56, Perimeter=46, Cost=2576
# Region M: Area=95, Perimeter=74, Cost=7030
# Region J: Area=2, Perimeter=6, Cost=12
# Region O: Area=1, Perimeter=4, Cost=4
# Region B: Area=5, Perimeter=12, Cost=60
# Region P: Area=2, Perimeter=6, Cost=12
# Region I: Area=104, Perimeter=62, Cost=6448
# Region U: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region R: Area=1, Perimeter=4, Cost=4
# Region R: Area=1, Perimeter=4, Cost=4
# Region C: Area=83, Perimeter=76, Cost=6308
# Region K: Area=101, Perimeter=54, Cost=5454
# Region D: Area=36, Perimeter=44, Cost=1584
# Region U: Area=1, Perimeter=4, Cost=4
# Region I: Area=1, Perimeter=4, Cost=4
# Region S: Area=1, Perimeter=4, Cost=4
# Region C: Area=1, Perimeter=4, Cost=4
# Region L: Area=2, Perimeter=6, Cost=12
# Region E: Area=1, Perimeter=4, Cost=4
# Region N: Area=30, Perimeter=36, Cost=1080
# Region B: Area=23, Perimeter=28, Cost=644
# Region U: Area=1, Perimeter=4, Cost=4
# Region P: Area=68, Perimeter=44, Cost=2992
# Region P: Area=2, Perimeter=6, Cost=12
# Region U: Area=2, Perimeter=6, Cost=12
# Region R: Area=5, Perimeter=10, Cost=50
# Region A: Area=1, Perimeter=4, Cost=4
# Region O: Area=1, Perimeter=4, Cost=4
# Region K: Area=1, Perimeter=4, Cost=4
# Region X: Area=17, Perimeter=22, Cost=374
# Region F: Area=9, Perimeter=18, Cost=162
# Region O: Area=3, Perimeter=8, Cost=24
# Region E: Area=1, Perimeter=4, Cost=4
# Region Q: Area=2, Perimeter=6, Cost=12
# Region R: Area=1, Perimeter=4, Cost=4
# Region J: Area=1, Perimeter=4, Cost=4
# Total fencing cost: 1549354

# %%
def find_regions(grid):
    rows, cols = len(grid), len(grid[0])
    visited = set()
    regions = []

    def dfs(r, c, plant_type):
        if (r, c) in visited or r < 0 or c < 0 or r >= rows or c >= cols or grid[r][c] != plant_type:
            return set()

        cells = {(r, c)}
        visited.add((r, c))

        for dr, dc in [(0, 1), (1, 0), (0, -1), (-1, 0)]:
            cells.update(dfs(r + dr, c + dc, plant_type))

        return cells

    for r in range(rows):
        for c in range(cols):
            if (r, c) not in visited:
                region = dfs(r, c, grid[r][c])
                if region:
                    regions.append(region)

    return regions

def count_sides(region, grid):
    rows, cols = len(grid), len(grid[0])
    sides = 0
    visited_edges = set()

    def trace_line(r, c, dr, dc):
        nr, nc = r + dr, c + dc
        return (nr < 0 or nc < 0 or nr >= rows or nc >= cols or (nr, nc) not in region)

    # Count horizontal lines
    for r, c in region:
        # Check up
        if (r, c, 'u') not in visited_edges and trace_line(r, c, -1, 0):
            start_c = c
            while (r, start_c-1) in region and trace_line(r, start_c-1, -1, 0):
                start_c -= 1
            end_c = c
            while (r, end_c+1) in region and trace_line(r, end_c+1, -1, 0):
                end_c += 1
            sides += 1
            for i in range(start_c, end_c+1):
                visited_edges.add((r, i, 'u'))

        # Check down
        if (r, c, 'd') not in visited_edges and trace_line(r, c, 1, 0):
            start_c = c
            while (r, start_c-1) in region and trace_line(r, start_c-1, 1, 0):
                start_c -= 1
            end_c = c
            while (r, end_c+1) in region and trace_line(r, end_c+1, 1, 0):
                end_c += 1
            sides += 1
            for i in range(start_c, end_c+1):
                visited_edges.add((r, i, 'd'))

    # Count vertical lines
    for r, c in region:
        # Check left
        if (r, c, 'l') not in visited_edges and trace_line(r, c, 0, -1):
            start_r = r
            while (start_r-1, c) in region and trace_line(start_r-1, c, 0, -1):
                start_r -= 1
            end_r = r
            while (end_r+1, c) in region and trace_line(end_r+1, c, 0, -1):
                end_r += 1
            sides += 1
            for i in range(start_r, end_r+1):
                visited_edges.add((i, c, 'l'))

        # Check right
        if (r, c, 'r') not in visited_edges and trace_line(r, c, 0, 1):
            start_r = r
            while (start_r-1, c) in region and trace_line(start_r-1, c, 0, 1):
                start_r -= 1
            end_r = r
            while (end_r+1, c) in region and trace_line(end_r+1, c, 0, 1):
                end_r += 1
            sides += 1
            for i in range(start_r, end_r+1):
                visited_edges.add((i, c, 'r'))

    return sides

def solve_part2(input_text):
    grid = [list(line.strip()) for line in input_text.strip().split('\n')]
    regions = find_regions(grid)

    total_price = 0
    for region in regions:
        area = len(region)
        num_sides = count_sides(region, grid)
        price = area * num_sides
        total_price += price

    return total_price

with open('input.txt', 'r') as f:
    input_text = f.read()

result = solve_part2(input_text)
print(result)
# Out:
# 937032
