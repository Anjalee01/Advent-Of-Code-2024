# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjalee01/Advent-Of-Code-2024/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def parse_input(file_path):
    with open(file_path, "r") as file:
        data = file.read().strip().split("\n\n")

    machines = []
    for block in data:
        lines = block.split("\n")
        button_a = tuple(map(int, lines[0].split("X+")[1].split(", Y+")))
        button_b = tuple(map(int, lines[1].split("X+")[1].split(", Y+")))
        prize = tuple(map(int, lines[2].split("X=")[1].split(", Y=")))
        machines.append((button_a, button_b, prize))

    return machines

def solve_claw_machine(button_a, button_b, prize):
    a, c = button_a
    b, d = button_b
    X, Y = prize

    min_cost = float('inf')
    best_na, best_nb = None, None

    # Iterate over possible n_A values
    for n_A in range(101):
        rem_x = X - n_A * a
        rem_y = Y - n_A * c

        if rem_x % b == 0 and rem_y % d == 0:
            n_B_x = rem_x // b
            n_B_y = rem_y // d

            if n_B_x == n_B_y and n_B_x >= 0:
                cost = 3 * n_A + n_B_x
                if cost < min_cost:
                    min_cost = cost
                    best_na, best_nb = n_A, n_B_x

    return min_cost if best_na is not None else None

def main(file_path):
    machines = parse_input(file_path)
    total_cost = 0
    prizes_won = 0

    for button_a, button_b, prize in machines:
        result = solve_claw_machine(button_a, button_b, prize)
        if result is not None:
            total_cost += result
            prizes_won += 1

    print(f"Prizes Won: {prizes_won}")
    print(f"Minimum Tokens Spent: {total_cost}")

# Example usage
main("input.txt")
# Out:
# Prizes Won: 135
# Minimum Tokens Spent: 26299

# %%
def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    gcd, x1, y1 = extended_gcd(b % a, a)
    x = y1 - (b // a) * x1
    y = x1
    return gcd, x, y

def find_solution(a1, a2, b1, b2, target_x, target_y):
    print(f"\nSolving for equations:")


    # Calculate determinant
    det = a1 * b2 - a2 * b1

    if det == 0:
        print("No solution - equations are dependent")
        return None

    # Using Cramer's rule
    n = (target_x * b2 - target_y * b1) / det
    m = (a1 * target_y - a2 * target_x) / det

    # Check if solution is integer and non-negative
    if n != int(n) or m != int(m) or n < 0 or m < 0:
        print(f"No valid solution: A={n}, B={m}")
        return None

    n = int(n)
    m = int(m)

    # Verify solution
    if (a1 * n + b1 * m == target_x) and (a2 * n + b2 * m == target_y):
        print(f"Found solution: A={n}, B={m}")
        return (n, m)

    return None

def solve_claw_machines_part2(input_data):
    total_tokens = 0
    possible_prizes = 0
    OFFSET = 10000000000000

    lines = input_data.strip().split('\n')

    for i in range(0, len(lines), 4):
        if i + 2 >= len(lines):
            break


        # Parse input
        a_line = lines[i].strip()
        ax = int(a_line[a_line.find('X+')+2:a_line.find(',')])
        ay = int(a_line[a_line.find('Y+')+2:])

        b_line = lines[i+1].strip()
        bx = int(b_line[b_line.find('X+')+2:b_line.find(',')])
        by = int(b_line[b_line.find('Y+')+2:])

        p_line = lines[i+2].strip()
        px = int(p_line[p_line.find('X=')+2:p_line.find(',')]) + OFFSET
        py = int(p_line[p_line.find('Y=')+2:]) + OFFSET


        # Find solution
        solution = find_solution(ax, ay, bx, by, px, py)

        if solution:
            n, m = solution
            tokens = 3 * n + m
            total_tokens += tokens
            possible_prizes += 1
            print(f"Tokens needed: {tokens}")
        else:
            print("No solution found")

    return total_tokens, possible_prizes

# Function to read input from file and process it
def read_input_file(file_path):
    with open(file_path, 'r') as file:
        input_data = file.read()
    return input_data

# Sample usage
input_file_path = 'input.txt'  # Path to the input file
input_data = read_input_file(input_file_path)
total_tokens, possible_prizes = solve_claw_machines_part2(input_data)
print(f"Total tokens needed: {total_tokens}")
# Out:
# Solving for equations:
# No valid solution: A=110213078658.66275, B=29390154394.310066
# No solution found
#
# Solving for equations:
# No valid solution: A=18201674651.058975, B=120131052115.78923
# No solution found
#
# Solving for equations:
# Found solution: A=124653739936, B=110803324116
# Tokens needed: 484764543924
#
# Solving for equations:
# No valid solution: A=27.0, B=192307692365.69232
# No solution found
#
# Solving for equations:
# Found solution: A=143557423031, B=129551820920
# Tokens needed: 560224090013
#
# Solving for equations:
# Found solution: A=148026315799, B=180921052826
# Tokens needed: 625000000223
#
# Solving for equations:
# No valid solution: A=98958333399.33333, B=65104166681.666664
# No solution found
#
# Solving for equations:
# Found solution: A=137524558219, B=203012442695
# Tokens needed: 615586117352
#
# Solving for equations:
# No valid solution: A=64516129101.258064, B=258064516219.03226
# No solution found
#
# Solving for equations:
# Found solution: A=134328358232, B=104477612098
# Tokens needed: 507462686794
#
# Solving for equations:
# No valid solution: A=2429543311.8697762, B=160349854280.40524
# No solution found
#
# Solving for equations:
# Found solution: A=155642023814, B=116731517391
# Tokens needed: 583657588833
#
# Solving for equations:
# No valid solution: A=65420560763.66355, B=87850467370.71962
# No solution found
#
# Solving for equations:
# No valid solution: A=37341299502.22181, B=119492158342.10979
# No solution found
#
# Solving for equations:
# Found solution: A=102925243717, B=146262188699
# Tokens needed: 455037919850
#
# Solving for equations:
# Found solution: A=104216011357, B=108953102864
# Tokens needed: 421601136935
#
# Solving for equations:
# Found solution: A=138483965474, B=145772594625
# Tokens needed: 561224491047
#
# Solving for equations:
# No valid solution: A=147704590844.36328, B=111776447198.78842
# No solution found
#
# Solving for equations:
# Found solution: A=105721393254, B=130597014844
# Tokens needed: 447761194606
#
# Solving for equations:
# Found solution: A=107663078029, B=101329955752
# Tokens needed: 424319189839
#
# Solving for equations:
# Found solution: A=109712810544, B=119393353130
# Tokens needed: 448531784762
#
# Solving for equations:
# Found solution: A=365168539813, B=112359550536
# Tokens needed: 1207865169975
#
# Solving for equations:
# Found solution: A=113571834425, B=122089721680
# Tokens needed: 462805224955
#
# Solving for equations:
# Found solution: A=163934426147, B=109289617750
# Tokens needed: 601092896191
#
# Solving for equations:
# Found solution: A=107223476613, B=118510157557
# Tokens needed: 440180587396
#
# Solving for equations:
# Found solution: A=126582278917, B=126582278007
# Tokens needed: 506329114758
#
# Solving for equations:
# Found solution: A=210954848420, B=103626943208
# Tokens needed: 736491488468
#
# Solving for equations:
# No valid solution: A=115207373314.8894, B=48963133736.55299
# No solution found
#
# Solving for equations:
# No valid solution: A=183486238547.11008, B=58977719613.178246
# No solution found
#
# Solving for equations:
# No valid solution: A=133441164597.43631, B=68742418153.649
# No solution found
#
# Solving for equations:
# No valid solution: A=53465724672.51804, B=97383998569.40787
# No solution found
#
# Solving for equations:
# No valid solution: A=72083879482.32896, B=62254259519.96593
# No solution found
#
# Solving for equations:
# No valid solution: A=26737967934.438503, B=120320855675.97327
# No solution found
#
# Solving for equations:
# Found solution: A=127814973038, B=115642118053
# Tokens needed: 499087037167
#
# Solving for equations:
# No valid solution: A=-7114905660.49911, B=138740661748.23267
# No solution found
#
# Solving for equations:
# No valid solution: A=135977337190.48158, B=96317280521.2578
# No solution found
#
# Solving for equations:
# Found solution: A=136165577095, B=130718954592
# Tokens needed: 539215685877
#
# Solving for equations:
# No valid solution: A=94850948522.48509, B=58717253894.205055
# No solution found
#
# Solving for equations:
# No valid solution: A=40363269440.82341, B=103430877932.10999
# No solution found
#
# Solving for equations:
# Found solution: A=188679245804, B=125786163511
# Tokens needed: 691823900923
#
# Solving for equations:
# Found solution: A=138067061467, B=118343195290
# Tokens needed: 532544379691
#
# Solving for equations:
# Found solution: A=124223602395, B=186335404076
# Tokens needed: 559006211261
#
# Solving for equations:
# No valid solution: A=151128557489.22473, B=9813542714.910696
# No solution found
#
# Solving for equations:
# Found solution: A=103795966901, B=127520759181
# Tokens needed: 438908659884
#
# Solving for equations:
# No valid solution: A=179704016949.31924, B=70472163568.41931
# No solution found
#
# Solving for equations:
# Found solution: A=112582781241, B=205298013928
# Tokens needed: 543046357651
#
# Solving for equations:
# No valid solution: A=101010101057.10101, B=20202020287.020203
# No solution found
#
# Solving for equations:
# Found solution: A=101694915365, B=103479036592
# Tokens needed: 408563782687
#
# Solving for equations:
# Found solution: A=181347150668, B=207253885739
# Tokens needed: 751295337743
#
# Solving for equations:
# No valid solution: A=87538620071.40268, B=97837281185.45006
# No solution found
#
# Solving for equations:
# No valid solution: A=57627118725.067795, B=89830508510.57628
# No solution found
#
# Solving for equations:
# No valid solution: A=14810426587.28436, B=121445497686.33176
# No solution found
#
# Solving for equations:
# No valid solution: A=149640287825.78418, B=20143884958.08633
# No solution found
#
# Solving for equations:
# No valid solution: A=143706640298.85925, B=91674925706.97919
# No solution found
#
# Solving for equations:
# Found solution: A=115445860273, B=107484076473
# Tokens needed: 453821657292
#
# Solving for equations:
# Found solution: A=196238757554, B=106295993560
# Tokens needed: 695012266222
#
# Solving for equations:
# Found solution: A=175438596814, B=116959064487
# Tokens needed: 643274854929
#
# Solving for equations:
# Found solution: A=215163934474, B=102459016577
# Tokens needed: 747950819999
#
# Solving for equations:
# No valid solution: A=128676470624.23529, B=110294117715.05882
# No solution found
#
# Solving for equations:
# Found solution: A=114942528878, B=114942528732
# Tokens needed: 459770115366
#
# Solving for equations:
# No valid solution: A=29013539676.837524, B=119277885279.33205
# No solution found
#
# Solving for equations:
# Found solution: A=138067061405, B=177514793120
# Tokens needed: 591715977335
#
# Solving for equations:
# No valid solution: A=160381447811.66364, B=8669267489.900738
# No solution found
#
# Solving for equations:
# Found solution: A=146945088907, B=123743232936
# Tokens needed: 564578499657
#
# Solving for equations:
# Found solution: A=503597122751, B=119904076916
# Tokens needed: 1630695445169
#
# Solving for equations:
# Found solution: A=149253731652, B=149253731575
# Tokens needed: 597014926531
#
# Solving for equations:
# Found solution: A=128865979478, B=150957290404
# Tokens needed: 537555228838
#
# Solving for equations:
# Found solution: A=117474302531, B=161527166085
# Tokens needed: 513950073678
#
# Solving for equations:
# Found solution: A=189873418148, B=101265822765
# Tokens needed: 670886077209
#
# Solving for equations:
# Found solution: A=214180206890, B=110782865585
# Tokens needed: 753323486255
#
# Solving for equations:
# No valid solution: A=88495575278.23894, B=61266167467.85773
# No solution found
#
# Solving for equations:
# Found solution: A=162232316649, B=103828682745
# Tokens needed: 590525632692
#
# Solving for equations:
# Found solution: A=107526881763, B=107526882052
# Tokens needed: 430107527341
#
# Solving for equations:
# No valid solution: A=121285627714.12311, B=163735597390.7162
# No solution found
#
# Solving for equations:
# No valid solution: A=73632093493.58754, B=77440650005.6524
# No solution found
#
# Solving for equations:
# No valid solution: A=390956194163.0024, B=18841262381.578426
# No solution found
#
# Solving for equations:
# No valid solution: A=63661828450.710724, B=99312452283.62872
# No solution found
#
# Solving for equations:
# No valid solution: A=47980188918.25925, B=99055873772.76103
# No solution found
#
# Solving for equations:
# No valid solution: A=105911330125.26108, B=78817734013.14778
# No solution found
#
# Solving for equations:
# Found solution: A=232142857587, B=107142856845
# Tokens needed: 803571429606
#
# Solving for equations:
# No valid solution: A=57868509931.87044, B=126989230126.3268
# No solution found
#
# Solving for equations:
# Found solution: A=131729668028, B=108820160597
# Tokens needed: 504009164681
#
# Solving for equations:
# Found solution: A=115406809150, B=106751298249
# Tokens needed: 452971725699
#
# Solving for equations:
# No valid solution: A=101234225504.8365, B=70725280914.96797
# No solution found
#
# Solving for equations:
# Found solution: A=105337078693, B=101825842813
# Tokens needed: 417837078892
#
# Solving for equations:
# Found solution: A=407673860569, B=119904077528
# Tokens needed: 1342925659235
#
# Solving for equations:
# No valid solution: A=112311930537.74867, B=103835558403.01292
# No solution found
#
# Solving for equations:
# Found solution: A=126582278638, B=126582278460
# Tokens needed: 506329114374
#
# Solving for equations:
# Found solution: A=180929095264, B=117359413505
# Tokens needed: 660146699297
#
# Solving for equations:
# Found solution: A=107526881945, B=107526881825
# Tokens needed: 430107527660
#
# Solving for equations:
# No valid solution: A=57655349202.16976, B=83279948757.80077
# No solution found
#
# Solving for equations:
# Found solution: A=124016939026, B=142165759236
# Tokens needed: 514216576314
#
# Solving for equations:
# No valid solution: A=19692792478.967705, B=143757384809.16425
# No solution found
#
# Solving for equations:
# Found solution: A=117647059091, B=117647058814
# Tokens needed: 470588236087
#
# Solving for equations:
# No valid solution: A=96362322358.9682, B=69862683717.67694
# No solution found
#
# Solving for equations:
# No valid solution: A=110294117720.05882, B=7659313823.490196
# No solution found
#
# Solving for equations:
# Found solution: A=192219679956, B=105263158038
# Tokens needed: 681922197906
#
# Solving for equations:
# Found solution: A=114717403668, B=125909345437
# Tokens needed: 470061556441
#
# Solving for equations:
# No valid solution: A=41412911162.043846, B=114494518969.41534
# No solution found
#
# Solving for equations:
# No valid solution: A=27243007675.042137, B=116236832573.31311
# No solution found
#
# Solving for equations:
# No valid solution: A=30581039769.35168, B=233180428211.55658
# No solution found
#
# Solving for equations:
# Found solution: A=191146881131, B=130784708633
# Tokens needed: 704225352026
#
# Solving for equations:
# Found solution: A=253920836557, B=112023898429
# Tokens needed: 873786408100
#
# Solving for equations:
# No valid solution: A=192307692360.69232, B=66.0
# No solution found
#
# Solving for equations:
# No valid solution: A=71094480916.19925, B=84190832601.78859
# No solution found
#
# Solving for equations:
# Found solution: A=135640785775, B=121608980616
# Tokens needed: 528531337941
#
# Solving for equations:
# Found solution: A=148986889210, B=107270560495
# Tokens needed: 554231228125
#
# Solving for equations:
# No valid solution: A=123060460164.11183, B=42803638361.25629
# No solution found
#
# Solving for equations:
# Found solution: A=229591836986, B=165816326431
# Tokens needed: 854591837389
#
# Solving for equations:
# Found solution: A=136116152657, B=235934664554
# Tokens needed: 644283122525
#
# Solving for equations:
# Found solution: A=100407055764, B=116689280895
# Tokens needed: 417910448187
#
# Solving for equations:
# Found solution: A=189415042128, B=105849582146
# Tokens needed: 674094708530
#
# Solving for equations:
# No valid solution: A=188481675434.67017, B=52356020952.40838
# No solution found
#
# Solving for equations:
# Found solution: A=186495177204, B=102893890794
# Tokens needed: 662379422406
#
# Solving for equations:
# No valid solution: A=90265918565.7114, B=65869724336.00561
# No solution found
#
# Solving for equations:
# No valid solution: A=105633802852.90141, B=146713615039.47418
# No solution found
#
# Solving for equations:
# No valid solution: A=146923783368.41965, B=52800734624.916435
# No solution found
#
# Solving for equations:
# Found solution: A=113319100227, B=106749876859
# Tokens needed: 446707177540
#
# Solving for equations:
# Found solution: A=121883656694, B=193905817339
# Tokens needed: 559556787421
#
# Solving for equations:
# Found solution: A=255986787605, B=123864574914
# Tokens needed: 891824937729
#
# Solving for equations:
# Found solution: A=117466802966, B=102145046165
# Tokens needed: 454545455063
#
# Solving for equations:
# Found solution: A=219058050897, B=104052573853
# Tokens needed: 761226726544
#
# Solving for equations:
# No valid solution: A=103730664332.21838, B=111010009137.18108
# No solution found
#
# Solving for equations:
# Found solution: A=107273678764, B=112506541235
# Tokens needed: 434327577527
#
# Solving for equations:
# No valid solution: A=14829461230.243204, B=227385071687.72913
# No solution found
#
# Solving for equations:
# Found solution: A=104671942734, B=119989788349
# Tokens needed: 434005616551
#
# Solving for equations:
# Found solution: A=166852057850, B=105672970310
# Tokens needed: 606229143860
#
# Solving for equations:
# No valid solution: A=242741551735.0752, B=38077106165.933365
# No solution found
#
# Solving for equations:
# Found solution: A=147625160727, B=102695763743
# Tokens needed: 545571245924
#
# Solving for equations:
# Found solution: A=107906204682, B=101680846637
# Tokens needed: 425399460683
#
# Solving for equations:
# Found solution: A=107923885276, B=173246237103
# Tokens needed: 497017892931
#
# Solving for equations:
# Found solution: A=105973025104, B=109184328845
# Tokens needed: 427103404157
#
# Solving for equations:
# Found solution: A=131578947329, B=115789474079
# Tokens needed: 510526316066
#
# Solving for equations:
# Found solution: A=113257828230, B=139906728987
# Tokens needed: 479680213677
#
# Solving for equations:
# No valid solution: A=136903563556.2269, B=78518220317.67426
# No solution found
#
# Solving for equations:
# No valid solution: A=82539682607.68254, B=77777777816.77777
# No solution found
#
# Solving for equations:
# Found solution: A=154542028049, B=101771579567
# Tokens needed: 565397663714
#
# Solving for equations:
# No valid solution: A=357698289294.05133, B=93312597235.62209
# No solution found
#
# Solving for equations:
# Found solution: A=164964650581, B=104739460656
# Tokens needed: 599633412399
#
# Solving for equations:
# Found solution: A=128322639868, B=137488542650
# Tokens needed: 522456462254
#
# Solving for equations:
# No valid solution: A=248447204995.9441, B=28232637007.2891
# No solution found
#
# Solving for equations:
# Found solution: A=100364963519, B=107208029422
# Tokens needed: 408302919979
#
# Solving for equations:
# No valid solution: A=105511592415.05887, B=45814244160.97293
# No solution found
#
# Solving for equations:
# Found solution: A=105701473677, B=112107623424
# Tokens needed: 429212044455
#
# Solving for equations:
# Found solution: A=157223375974, B=112726194122
# Tokens needed: 584396322044
#
# Solving for equations:
# Found solution: A=125523012686, B=292887029511
# Tokens needed: 669456067569
#
# Solving for equations:
# Found solution: A=107805088637, B=112117292068
# Tokens needed: 435532557979
#
# Solving for equations:
# Found solution: A=109034267906, B=151869159165
# Tokens needed: 478971962883
#
# Solving for equations:
# Found solution: A=131712259724, B=121580546817
# Tokens needed: 516717325989
#
# Solving for equations:
# Found solution: A=106463878495, B=114068441125
# Tokens needed: 433460076610
#
# Solving for equations:
# No valid solution: A=27483313741.394974, B=119748724047.00667
# No solution found
#
# Solving for equations:
# Found solution: A=120068610771, B=102915951989
# Tokens needed: 463121784302
#
# Solving for equations:
# Found solution: A=105421686796, B=110441767213
# Tokens needed: 426706827601
#
# Solving for equations:
# Found solution: A=110722610932, B=139860140013
# Tokens needed: 472027972809
#
# Solving for equations:
# No valid solution: A=37376826463.652054, B=156303092172.9086
# No solution found
#
# Solving for equations:
# Found solution: A=143678161102, B=114942528652
# Tokens needed: 545977011958
#
# Solving for equations:
# Found solution: A=112834979030, B=110484250227
# Tokens needed: 448989187317
#
# Solving for equations:
# Found solution: A=108038820726, B=104376488040
# Tokens needed: 428492950218
#
# Solving for equations:
# Found solution: A=193756727621, B=204520990769
# Tokens needed: 785791173632
#
# Solving for equations:
# No valid solution: A=101791530976.62541, B=52931596151.205215
# No solution found
#
# Solving for equations:
# No valid solution: A=116166505361.29816, B=62923523728.32817
# No solution found
#
# Solving for equations:
# No valid solution: A=279569892520.1183, B=8602150628.634409
# No solution found
#
# Solving for equations:
# No valid solution: A=175438596502.22806, B=87719298311.61403
# No solution found
#
# Solving for equations:
# No valid solution: A=70438036610.73146, B=94651111654.26414
# No solution found
#
# Solving for equations:
# No valid solution: A=109018830529.27255, B=237859266614.59464
# No solution found
#
# Solving for equations:
# Found solution: A=102493074911, B=132963989216
# Tokens needed: 440443213949
#
# Solving for equations:
# Found solution: A=115681233920, B=141388174967
# Tokens needed: 488431876727
#
# Solving for equations:
# No valid solution: A=127343473738.97559, B=109656880130.89565
# No solution found
#
# Solving for equations:
# Found solution: A=157170923563, B=137524558283
# Tokens needed: 609037328972
#
# Solving for equations:
# No valid solution: A=86077039004.86012, B=83925113009.11362
# No solution found
#
# Solving for equations:
# No valid solution: A=187586206931.55173, B=52413793118.44827
# No solution found
#
# Solving for equations:
# No valid solution: A=89051859627.36249, B=73336825650.12206
# No solution found
#
# Solving for equations:
# Found solution: A=110864745190, B=149667405738
# Tokens needed: 482261641308
#
# Solving for equations:
# Found solution: A=169491525824, B=119271814174
# Tokens needed: 627746391646
#
# Solving for equations:
# Found solution: A=100200400943, B=190380761582
# Tokens needed: 490981964411
#
# Solving for equations:
# No valid solution: A=25793970713.358376, B=95115266867.384
# No solution found
#
# Solving for equations:
# Found solution: A=221370796143, B=106428267400
# Tokens needed: 770540655829
#
# Solving for equations:
# Found solution: A=131233595835, B=118110236327
# Tokens needed: 511811023832
#
# Solving for equations:
# No valid solution: A=84470435444.62833, B=97465886994.57115
# No solution found
#
# Solving for equations:
# Found solution: A=165562914041, B=198675496910
# Tokens needed: 695364239033
#
# Solving for equations:
# No valid solution: A=99800399274.5968, B=9980040009.159681
# No solution found
#
# Solving for equations:
# Found solution: A=112743423301, B=126409292978
# Tokens needed: 464639562881
#
# Solving for equations:
# No valid solution: A=117150890358.76663, B=37488284951.965324
# No solution found
#
# Solving for equations:
# Found solution: A=119937082177, B=104207628965
# Tokens needed: 464018875496
#
# Solving for equations:
# No valid solution: A=134730538929.15569, B=61543579563.65137
# No solution found
#
# Solving for equations:
# No valid solution: A=40629761305.15236, B=279329608945.5475
# No solution found
#
# Solving for equations:
# Found solution: A=134099616877, B=119731800776
# Tokens needed: 522030651407
#
# Solving for equations:
# No valid solution: A=113753878066.11272, B=82730093147.3547
# No solution found
#
# Solving for equations:
# Found solution: A=126792766524, B=101849927450
# Tokens needed: 482228227022
#
# Solving for equations:
# Found solution: A=138518913242, B=186467768153
# Tokens needed: 602024507879
#
# Solving for equations:
# No valid solution: A=102827763531.14395, B=47741461691.209694
# No solution found
#
# Solving for equations:
# No valid solution: A=206124852801.9623, B=32391048305.108364
# No solution found
#
# Solving for equations:
# Found solution: A=102915952124, B=113831280265
# Tokens needed: 422579136637
#
# Solving for equations:
# Found solution: A=141509434055, B=314465409559
# Tokens needed: 738993711724
#
# Solving for equations:
# Found solution: A=128865979428, B=112464854775
# Tokens needed: 499062793059
#
# Solving for equations:
# Found solution: A=156514382794, B=109983079553
# Tokens needed: 579526227935
#
# Solving for equations:
# Found solution: A=116086235533, B=265339967502
# Tokens needed: 613598674101
#
# Solving for equations:
# No valid solution: A=89285714326.71428, B=39062500041.0
# No solution found
#
# Solving for equations:
# No valid solution: A=106273568808.00171, B=54850874233.807335
# No solution found
#
# Solving for equations:
# Found solution: A=125052105080, B=120883701832
# Tokens needed: 496040017072
#
# Solving for equations:
# No valid solution: A=130240130243.13023, B=22385022453.022385
# No solution found
#
# Solving for equations:
# Found solution: A=132032147237, B=100459242244
# Tokens needed: 496555683955
#
# Solving for equations:
# No valid solution: A=100957804897.91069, B=90603158244.22754
# No solution found
#
# Solving for equations:
# No valid solution: A=94962176088.40785, B=75647835205.291
# No solution found
#
# Solving for equations:
# Found solution: A=152439024462, B=102896341712
# Tokens needed: 560213415098
#
# Solving for equations:
# Found solution: A=112359550785, B=112359550620
# Tokens needed: 449438202975
#
# Solving for equations:
# Found solution: A=105263157694, B=100478469139
# Tokens needed: 416267942221
#
# Solving for equations:
# No valid solution: A=64102564169.5641, B=256410256437.2564
# No solution found
#
# Solving for equations:
# No valid solution: A=112427833494.26283, B=82041932600.29991
# No solution found
#
# Solving for equations:
# No valid solution: A=93377139955.78922, B=53605395190.63825
# No solution found
#
# Solving for equations:
# No valid solution: A=53859964116.35727, B=318671454282.0305
# No solution found
#
# Solving for equations:
# Found solution: A=120772947114, B=193236714940
# Tokens needed: 555555556282
#
# Solving for equations:
# Found solution: A=157938487060, B=103906899578
# Tokens needed: 577722360758
#
# Solving for equations:
# Found solution: A=145801910920, B=105580693530
# Tokens needed: 542986426290
#
# Solving for equations:
# No valid solution: A=122649223306.58626, B=96075224886.90924
# No solution found
#
# Solving for equations:
# No valid solution: A=111621799131.76166, B=70037207307.36026
# No solution found
#
# Solving for equations:
# Found solution: A=103931314947, B=203343877576
# Tokens needed: 515137822417
#
# Solving for equations:
# No valid solution: A=51360091392.82899, B=116035761877.35439
# No solution found
#
# Solving for equations:
# No valid solution: A=105737562926.84677, B=90136938853.88577
# No solution found
#
# Solving for equations:
# Found solution: A=114057599250, B=134017679099
# Tokens needed: 476190476849
#
# Solving for equations:
# Found solution: A=159010600796, B=147232037940
# Tokens needed: 624263840328
#
# Solving for equations:
# Found solution: A=163043478302, B=108695652436
# Tokens needed: 597826087342
#
# Solving for equations:
# Found solution: A=187477891780, B=116731517594
# Tokens needed: 679165192934
#
# Solving for equations:
# No valid solution: A=95191603664.39932, B=97632413989.4352
# No solution found
#
# Solving for equations:
# Found solution: A=245901639709, B=117096018876
# Tokens needed: 854800938003
#
# Solving for equations:
# Found solution: A=121726300370, B=106971597347
# Tokens needed: 472150498457
#
# Solving for equations:
# No valid solution: A=116279069798.44186, B=348837209351.32556
# No solution found
#
# Solving for equations:
# Found solution: A=108794197603, B=117860381106
# Tokens needed: 444242973915
#
# Solving for equations:
# Found solution: A=117582718154, B=139458572866
# Tokens needed: 492206727328
#
# Solving for equations:
# Found solution: A=278128950744, B=113780025698
# Tokens needed: 948166877930
#
# Solving for equations:
# No valid solution: A=152597402637.4026, B=107142857172.85715
# No solution found
#
# Solving for equations:
# Found solution: A=203562341168, B=114503816780
# Tokens needed: 725190840284
#
# Solving for equations:
# Found solution: A=578512398334, B=110192836944
# Tokens needed: 1845730031946
#
# Solving for equations:
# No valid solution: A=94587493438.42407, B=99842354264.61429
# No solution found
#
# Solving for equations:
# No valid solution: A=97806757601.7949, B=29638411396.14997
# No solution found
#
# Solving for equations:
# Found solution: A=195145169123, B=123750595067
# Tokens needed: 709186102436
#
# Solving for equations:
# Found solution: A=100414756635, B=133158699116
# Tokens needed: 434402969021
#
# Solving for equations:
# No valid solution: A=72950102182.14297, B=172162241076.13745
# No solution found
#
# Solving for equations:
# Found solution: A=116731517718, B=188993885465
# Tokens needed: 539188438619
#
# Solving for equations:
# Found solution: A=104691741244, B=131834044127
# Tokens needed: 445909267859
#
# Solving for equations:
# Found solution: A=131964809536, B=146627566140
# Tokens needed: 542521994748
#
# Solving for equations:
# No valid solution: A=141509433967.26416, B=47169811404.754715
# No solution found
#
# Solving for equations:
# Found solution: A=255102041081, B=153061224993
# Tokens needed: 918367348236
#
# Solving for equations:
# Found solution: A=129358830180, B=123734533192
# Tokens needed: 511811023732
#
# Solving for equations:
# No valid solution: A=163043478291.86957, B=54347826105.95652
# No solution found
#
# Solving for equations:
# Found solution: A=191972077168, B=139616055825
# Tokens needed: 715532287329
#
# Solving for equations:
# Found solution: A=103359172939, B=129198966786
# Tokens needed: 439276485603
#
# Solving for equations:
# Found solution: A=118858954320, B=108293713741
# Tokens needed: 464870576701
#
# Solving for equations:
# No valid solution: A=148104265418.8436, B=154028436076.95734
# No solution found
#
# Solving for equations:
# No valid solution: A=43572984819.45534, B=172311348860.937
# No solution found
#
# Solving for equations:
# No valid solution: A=92695587711.02596, B=118650352267.23322
# No solution found
#
# Solving for equations:
# Found solution: A=144092219001, B=115273775452
# Tokens needed: 547550432455
#
# Solving for equations:
# Found solution: A=183639399078, B=108514190439
# Tokens needed: 659432387673
#
# Solving for equations:
# Found solution: A=116995073960, B=153940887005
# Tokens needed: 504926108885
#
# Solving for equations:
# No valid solution: A=52316890942.91331, B=142002989576.62183
# No solution found
#
# Solving for equations:
# Found solution: A=160218835687, B=105509964882
# Tokens needed: 586166471943
#
# Solving for equations:
# No valid solution: A=38975501167.58575, B=122494432139.26949
# No solution found
#
# Solving for equations:
# No valid solution: A=90376160283.4895, B=178309721572.72253
# No solution found
#
# Solving for equations:
# Found solution: A=146455770399, B=134739308905
# Tokens needed: 574106620102
#
# Solving for equations:
# Found solution: A=130932896918, B=188216039356
# Tokens needed: 581014730110
#
# Solving for equations:
# Found solution: A=103092783304, B=103092783825
# Tokens needed: 412371133737
#
# Solving for equations:
# No valid solution: A=79295154280.02203, B=96916299594.47136
# No solution found
#
# Solving for equations:
# No valid solution: A=48724562934.00917, B=174835196400.32703
# No solution found
#
# Solving for equations:
# No valid solution: A=31413612624.445026, B=136125654476.26178
# No solution found
#
# Solving for equations:
# Found solution: A=113770106074, B=137308748834
# Tokens needed: 478619067056
#
# Solving for equations:
# No valid solution: A=105050505097.50505, B=44444444518.44444
# No solution found
#
# Solving for equations:
# Found solution: A=268324607419, B=117801047411
# Tokens needed: 922774869668
#
# Solving for equations:
# Found solution: A=114678899377, B=321100917229
# Tokens needed: 665137615360
#
# Solving for equations:
# Found solution: A=119760479126, B=107784431272
# Tokens needed: 467065868650
#
# Solving for equations:
# No valid solution: A=78873239451.61972, B=166197183167.59155
# No solution found
#
# Solving for equations:
# No valid solution: A=94299185695.94257, B=135019288548.7814
# No solution found
#
# Solving for equations:
# Found solution: A=134868421163, B=161184210647
# Tokens needed: 565789474136
#
# Solving for equations:
# Found solution: A=139140955948, B=108892922143
# Tokens needed: 526315789987
#
# Solving for equations:
# Found solution: A=150234741987, B=107981220773
# Tokens needed: 558685446734
#
# Solving for equations:
# Found solution: A=113445378340, B=159663865845
# Tokens needed: 500000000865
#
# Solving for equations:
# No valid solution: A=108919635041.03415, B=55931704525.09862
# No solution found
#
# Solving for equations:
# No valid solution: A=123375555198.99835, B=26320118504.53298
# No solution found
#
# Solving for equations:
# Found solution: A=130151843577, B=151843818149
# Tokens needed: 542299348880
#
# Solving for equations:
# Found solution: A=152963671384, B=210325048164
# Tokens needed: 669216062316
#
# Solving for equations:
# Found solution: A=101522842768, B=152284264127
# Tokens needed: 456852792431
#
# Solving for equations:
# No valid solution: A=148809523825.5238, B=55272108927.537415
# No solution found
#
# Solving for equations:
# Found solution: A=180995475304, B=226244343841
# Tokens needed: 769230769753
#
# Solving for equations:
# Found solution: A=155440414599, B=138169257607
# Tokens needed: 604490501404
#
# Solving for equations:
# No valid solution: A=39682539753.53968, B=264550264605.26456
# No solution found
#
# Solving for equations:
# No valid solution: A=173830594269.57648, B=22123893832.309734
# No solution found
#
# Solving for equations:
# No valid solution: A=201238390126.87924, B=73529411839.70589
# No solution found
#
# Solving for equations:
# Found solution: A=138004246281, B=134465676095
# Tokens needed: 548478414938
#
# Solving for equations:
# No valid solution: A=120357634133.7923, B=89408528287.07428
# No solution found
#
# Solving for equations:
# Found solution: A=108267716535, B=147637795316
# Tokens needed: 472440944921
#
# Solving for equations:
# No valid solution: A=125551408288.74075, B=67865626102.400406
# No solution found
#
# Solving for equations:
# Found solution: A=115894039808, B=118259224462
# Tokens needed: 465941343886
#
# Solving for equations:
# No valid solution: A=39793076029.77517, B=145244727484.42938
# No solution found
#
# Solving for equations:
# Found solution: A=125223613721, B=157423971547
# Tokens needed: 533094812710
#
# Solving for equations:
# No valid solution: A=82730093082.3547, B=93071354758.27405
# No solution found
#
# Solving for equations:
# Found solution: A=119760479251, B=115154306753
# Tokens needed: 474435744506
#
# Solving for equations:
# No valid solution: A=122084548133.95627, B=32798833844.24198
# No solution found
#
# Solving for equations:
# Found solution: A=149700599020, B=134730539107
# Tokens needed: 583832336167
#
# Solving for equations:
# Found solution: A=158524749154, B=100291168126
# Tokens needed: 575865415588
#
# Solving for equations:
# Found solution: A=116861435631, B=217028381056
# Tokens needed: 567612687949
#
# Solving for equations:
# Found solution: A=101214574753, B=121457490238
# Tokens needed: 425101214497
#
# Solving for equations:
# No valid solution: A=133909287310.01944, B=49676025972.92657
# No solution found
#
# Solving for equations:
# No valid solution: A=113846153864.15384, B=70769230868.23077
# No solution found
#
# Solving for equations:
# No valid solution: A=156250000043.0, B=52083333411.333336
# No solution found
#
# Solving for equations:
# Found solution: A=179186768099, B=103376981364
# Tokens needed: 640937285661
#
# Solving for equations:
# Found solution: A=146686899495, B=136570561573
# Tokens needed: 576631260058
#
# Solving for equations:
# No valid solution: A=255341323635.0448, B=104220948431.63054
# No solution found
#
# Solving for equations:
# No valid solution: A=314716312100.7376, B=31028368850.32624
# No solution found
#
# Solving for equations:
# Found solution: A=226130653546, B=115577889637
# Tokens needed: 793969850275
#
# Solving for equations:
# No valid solution: A=118512464259.9289, B=65386187263.96077
# No solution found
#
# Solving for equations:
# Found solution: A=190871369496, B=165975104058
# Tokens needed: 738589212546
#
# Solving for equations:
# Found solution: A=107665805453, B=133505598709
# Tokens needed: 456503015068
#
# Solving for equations:
# No valid solution: A=110811620319.5825, B=-5989817229.572027
# No solution found
#
# Solving for equations:
# No valid solution: A=112359550614.79776, B=134831460737.1573
# No solution found
#
# Solving for equations:
# Found solution: A=184696569816, B=151715040024
# Tokens needed: 705804749472
#
# Solving for equations:
# Found solution: A=134897360987, B=129032258221
# Tokens needed: 533724341182
#
# Solving for equations:
# Found solution: A=122008446846, B=136086344575
# Tokens needed: 502111685113
#
# Solving for equations:
# Found solution: A=173370319017, B=152565880764
# Tokens needed: 672676837815
#
# Solving for equations:
# Found solution: A=183727034504, B=288713911056
# Tokens needed: 839895014568
#
# Solving for equations:
# Found solution: A=232558139890, B=116279069766
# Tokens needed: 813953489436
#
# Solving for equations:
# Found solution: A=129081245485, B=136674259743
# Tokens needed: 523917996198
# Total tokens needed: 107824497933339
